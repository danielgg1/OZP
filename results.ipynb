# %%
import pandas as pd

# %%
og = pd.read_csv('Results/EN_GEMMA_INCOMPLETE.csv' ,na_values='NA')
newdf = pd.read_csv('Results/en_results (1).csv', na_values='NA')
end = pd.concat([og, newdf], axis=0)
end = end.reset_index()
end = end.drop(labels=['index', 'Unnamed: 0'], axis = 1)

# %%
end.to_csv('final.csv', index = True)

# %%
for i in range(len(end)):
    end.at[i, 'Unnamed: 0'] = i

# %%
end
# Out:
#      Language  Model  BeamSearch  Temperature     Category  \
# 0          EN  Gemma         NaN          1.4   SportsTeam
# 1          EN  Gemma         NaN          1.4    Astronaut
# 2          EN  Gemma         NaN          1.4      Airport
# 3          EN  Gemma         NaN          1.4      Athlete
# 4          EN  Gemma         NaN          1.4         City
# ...       ...    ...         ...          ...          ...
# 5332       EN  Gemma         NaN          0.8         Film
# 5333       EN  Gemma         NaN          0.8    Scientist
# 5334       EN  Gemma         NaN          0.8      Company
# 5335       EN  Gemma         NaN          0.8  MusicalWork
# 5336       EN  Gemma         NaN          0.8         City
#
#                                            Input String  \
# 0     Estádio Municipal Coaracy da Mata Fonseca has ...
# 1     Nie Haisheng has birthDate 1964-10-13. Nie Hai...
# 2                  MotorSport Vision has city Fawkham.
# ...
