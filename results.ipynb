# %%
import pandas as pd

# %%
og = pd.read_csv('Results/RU-GEMMA-INCOMPLETE.csv' ,na_values='NA')
newdf = pd.read_csv('Results/rugem.csv', na_values='NA')
end = pd.concat([og, newdf], axis=0)
end = end.reset_index()
end = end.drop(labels=['index', 'Unnamed: 0'], axis = 1)

# %%
end.to_csv('final.csv', index = True)

# %%
for i in range(len(end)):
    end.at[i, 'Unnamed: 0'] = i

# %%
end
# Out:
#       Unnamed: 0 Language  Model  BeamSearch  Temperature         Category  \
# 0            0.0       RU  Gemma         4.0          NaN             Food
# 1            1.0       RU  Gemma         4.0          NaN       SportsTeam
# 2            2.0       RU  Gemma         4.0          NaN             Food
# 3            3.0       RU  Gemma         4.0          NaN  ComicsCharacter
# 4            4.0       RU  Gemma         4.0          NaN       University
# ...          ...      ...    ...         ...          ...              ...
# 3301      3301.0      NaN    NaN         NaN          NaN              NaN
# 3302      3302.0      NaN    NaN         NaN          NaN              NaN
# 3303      3303.0      NaN    NaN         NaN          NaN              NaN
# 3304      3304.0      NaN    NaN         NaN          NaN              NaN
# 3305      3305.0      NaN    NaN         NaN          NaN              NaN
#
#                                            Input String  \
# 0     “Запеченная Аляска” имеет course Десерт. Десер...
# 1     Футбольный клуб “Акрон” (США) имеет fullName A...
# 2     бандеха паиса имеет ingredient Авокадо. бандех...
# 3     Эйприл О’Нил имеет creator Лэрд, Питер. Лэрд, ...
# 4     Румыния имеет ethnicGroup Немцы в Румынии. Рум...
# ...                                                 ...
# 3301                                                NaN
# 3302                                                NaN
# 3303                                                NaN
# 3304                                                NaN
# 3305                                                NaN
#
#                                                Original  \
# 0     ['“Запеченная Аляска” и печенье – десерты. "За...
# 1     ['Насчитывающий 3000 членов сильный Футбольный...
# 2     ['Часть колумбийской, кухни бандеха паиса - эт...
# 3     ["Эйприл О 'Нил был создан Питером Лэрдом, из ...
# 4     ['Университет «1 декабря 1918» находится в Рум...
# ...                                                 ...
# 3301                                                NaN
# 3302                                                NaN
# 3303                                                NaN
# 3304                                                NaN
# 3305                                                NaN
#
#                                               Generated TextID  BERTScore F1  \
# 0     Запеченная Аляска — это десерт в виде печенья,...    Id1      0.827756
# 1     Футбольный клуб “Акрон” из США, известный такж...    Id2      0.792789
# 2     Бандеха паиса – это блюдо колумбийской кухни и...    Id3      0.824059
# 3     Эйприл О’Нил – создатель Лэрда Питера. Лэрд Пи...    Id4      0.835568
# 4     В Румынии проживают немцы. Президент Румынии —...    Id5      0.829633
# ...                                                 ...    ...           ...
# 3301                                                NaN    NaN           NaN
# 3302                                                NaN    NaN           NaN
# 3303                                                NaN    NaN           NaN
# 3304                                                NaN    NaN           NaN
# 3305                                                NaN    NaN           NaN
#
#         chrF++  Sentence BLEU  Corpus BLEU
# 0     0.389813       0.576552     0.656721
# 1     0.413888       0.514352          NaN
# 2     0.386694       0.630947          NaN
# 3     0.397300       0.609433          NaN
# 4     0.463342       0.663400          NaN
# ...        ...            ...          ...
# 3301       NaN            NaN          NaN
# 3302       NaN            NaN          NaN
# 3303       NaN            NaN          NaN
# 3304       NaN            NaN          NaN
# 3305       NaN            NaN          NaN
#
# [4408 rows x 14 columns]
